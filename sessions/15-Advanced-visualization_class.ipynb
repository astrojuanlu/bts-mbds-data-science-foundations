# %% [markdown]
# ![BTS](img/Logo-BTS.jpg)
#
# # Session 15: Advanced Visualization
#
# ### Juan Luis Cano Rodríguez <juan.cano@bts.tech> - Data Science Foundations (2018-11-16)
#
# Open this notebook in Google Colaboratory: [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Juanlu001/bts-mbds-data-science-foundations/blob/master/sessions/15-Advanced-Visualization.ipynb)

# %% [markdown]
# ## Anatomy of a matplotlib figure
#
# (Taken from https://matplotlib.org/gallery/showcase/anatomy.html)
#
# ![Anatomy of a matplotlib figure](img/matplotlib_anatomy.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# plt.ion()
# %matplotlib inline

import numpy as np

# %%
print(plt.style.available)
# Out:
# ['seaborn-talk', 'seaborn-white', 'classic', 'seaborn-bright', 'seaborn-dark', 'seaborn-pastel', 'dark_background', 'seaborn-whitegrid', 'bmh', 'seaborn-notebook', 'seaborn-ticks', 'tableau-colorblind10', 'seaborn-muted', 'grayscale', 'Solarize_Light2', 'seaborn-poster', 'seaborn', '_classic_test', 'seaborn-darkgrid', 'seaborn-deep', 'ggplot', 'fast', 'fivethirtyeight', 'seaborn-colorblind', 'seaborn-paper', 'seaborn-dark-palette', 'pybonacci']

# %%
import seaborn as sns
sns.set()

# %%
plt.style.use("fivethirtyeight")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
with plt.xkcd():
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 5))

    df = pd.DataFrame(np.random.randn(500, 2))

    df.plot.scatter(x=0, y=1, ax=axes[0])

    axes[0].set_xlim(-1, 1)
    axes[0].set_title("Title of the ax")

    axes[1].grid(True)

    fig.suptitle("Title of the figure")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
with plt.style.context("fivethirtyeight"):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 5))

    df = pd.DataFrame(np.random.randn(500, 2))

    df.plot.scatter(x=0, y=1, ax=axes[0])

    axes[0].set_xlim(-1, 1)
    axes[0].set_title("Title of the ax")

    axes[1].grid(True)

    fig.suptitle("Title of the figure")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 5))

df = pd.DataFrame(np.random.randn(500, 2))

df.plot.scatter(x=0, y=1, ax=axes[0])

axes[0].set_xlim(-1, 1)
axes[0].set_title("Title of the ax")

axes[1].grid(True)

fig.suptitle("Title of the figure")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# Text(0.5, 0.98, 'Title of the figure')

# %%
ax.set_xlim(-1, 1)
# Out:
# (-1, 1)

# %%
ax.grid(True)

# %%
ax

# %%
ax.figure

# %%
ax.set_xticklabels('abcdefghij')
# Out:
# [Text(-1.0, 0, 'a'),
#  Text(-0.75, 0, 'b'),
#  Text(-0.5, 0, 'c'),
#  Text(-0.25, 0, 'd'),
#  Text(0.0, 0, 'e'),
#  Text(0.25, 0, 'f'),
#  Text(0.5, 0, 'g'),
#  Text(0.75, 0, 'h'),
#  Text(1.0, 0, 'i')]

# %%
#list(ax.get_yticklabels())

# %%
ax.figure

# %%
list(ax.get_xticklabels())
# Out:
# [Text(-1.0, 0, '−1.00'),
#  Text(-0.75, 0, '−0.75'),
#  Text(-0.5, 0, '−0.50'),
#  Text(-0.25, 0, '−0.25'),
#  Text(0.0, 0, '0.00'),
#  Text(0.25, 0, '0.25'),
#  Text(0.5, 0, '0.50'),
#  Text(0.75, 0, '0.75'),
#  Text(1.0, 0, '1.00')]

# %% [markdown]
# ## Interactive widgets
#
# Widgets are basic User Interface (UI) building blocks that maintain a state and can trigger changes using callbacks.

# %%
from ipywidgets import IntSlider

# %%
IntSlider()
# Out:
# IntSlider(value=0)

# %% [markdown]
# The easiest way to bind some interactivity to a widget is to use the `@interact` decorator on a function:

# %%
from ipywidgets import interact

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Intermezzo: decorators

# %%
def analyze(text, a):
    displacy.render(nlp(text), jupyter=True)

# %%
misterious_object = interact(text="", a=True)

# %%
misterious_object(analyze)
# Out:
# interactive(children=(Text(value='', description='text'), Checkbox(value=True, description='a'), Output()), _d…
# <function __main__.analyze(text, a)>

# %%
def my_wrapper(function):
    def wrapper():
        print("I am going to call the function:")
        function()
        print("I called the function")

    return wrapper

# %%
def func():
    print("42")

# %%
func()
# Out:
# 42

# %%
new_func = my_wrapper(func)

# %%
new_func()
# Out:
# I am going to call the function:
# 42
# I called the function

# %%
@my_wrapper
def func():
    print("42")

# %%
func()
# Out:
# I am going to call the function:
# 42
# I called the function

# %%
#@interact(text="", a=True)
def analyze(text):
    displacy.render(nlp(text), jupyter=True)

# %%
analyze("Hello world!")
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">world!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>

# %%
from ipywidgets import Textarea

# %%
text_area = Textarea()

# %%
def dummy_handler(stuff):
    print(stuff)

# %%
def handler(stuff):
    analyze(stuff['new'])

# %%
text_area.observe(dummy_handler, 'value')

# %%
text_area
# Out:
# Textarea(value='')
# {'name': 'value', 'old': '', 'new': 'H', 'owner': Textarea(value='H'), 'type': 'change'}

# %%
text_area.observe(handler, "value")

# %%
text_area
# Out:
# Textarea(value='')
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">H</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ho</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hol</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hola</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="50" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial"></svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">H</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">w</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PUNCT</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">wo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M225.0,91.5 L233.0,79.5 217.0,79.5" fill="currentColor"/>
# </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">wor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">worl</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">X</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">world</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">world!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>

# %%
text_area
# Out:
# Textarea(value='')

# %% [markdown]
# But we can also react to our own events using the `observe(callback, 'values')` method:

# %% [markdown]
# ## Plotly for interactive plotting

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(500, 2), columns=['x', 'y'])
df.head()
# Out:
#           x         y
# 0 -1.623955 -1.812398
# 1  1.074847 -0.191501
# 2  1.586012 -0.684296
# 3 -1.054714 -0.877529
# 4  0.128907 -0.560698

# %%
from plotly import graph_objs as go

# %%
fig = go.FigureWidget()
fig
# Out:
# FigureWidget({
#     'data': [], 'layout': {}
# })

# %%
sc = fig.add_scatter(
    x=df['x'],
    y=df['y'],
    mode="markers",
)

# %%
sc.marker.size = 10 * np.abs(np.random.randn(500))

# %%
len(fig.data)
# Out:
# 2

# %%
fig.data = []

# %%
fig.data = [fig.data[1]]

# %%
fig.add_scatter(
    x=df[0],
    y=df[1],
)
# Out:
# Scatter({
#     'uid': 'a201464a-f22b-11e8-b478-a0afbda902ef',
#     'x': array([-0.61530845, -0.66323157,  1.42098931, ...,  0.97133033,  0.34821325,
#                 -1.14563417]),
#     'y': array([-0.43355383, -1.12742505, -2.27478711, ...,  0.60791051, -0.98840247,
#                 -0.5227977 ])
# })

# %%
fig.add_scatter(
    x=df[0],
    y=df[1],
    mode="markers",
)
# Out:
# Scatter({
#     'mode': 'markers',
#     'uid': 'bf0e82f2-f22b-11e8-b478-a0afbda902ef',
#     'x': array([-0.61530845, -0.66323157,  1.42098931, ...,  0.97133033,  0.34821325,
#                 -1.14563417]),
#     'y': array([-0.43355383, -1.12742505, -2.27478711, ...,  0.60791051, -0.98840247,
#                 -0.5227977 ])
# })

# %% [markdown]
# ## Exercise 1: "Gapminder" interactive visualization
#
# We will reproduce an example similar to this:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("jbkSRLYSojo", width=800, height=600)

# %% [markdown]
# 1. Load all the datasets in the `data/gapminder` directory, indexing them by `Country`.
# 2. Create a function that receives a `year` _as an integer_ and returns a new dataframe with `Country` as the index and the columns `Fertility`, `Life expectancy`, `Population` and `Group`.
# 3. Create a Plotly `FigureWidget` and visualize a scatter plot of `Life expectancy` vs `Fertility`, using the `Population` as bubble size (you will need some scaling) and coloring by `Group`. _Hint: it will be easier to do as many scatters as regions_
# 4. Decorate the figure with proper X and Y axis labels, a title, a big text showing the year, and a legend (if not present). _Note: The legend might not show the colors_
# 5. Create a function `update_year` that receives a `year` _as an integer_ and updates the data of the existing figure with the values from the selected year. _Note: The update might not be very efficient_
# 6. Create an horizontal slider that ranges from the minimum to the maximum year
# 7. Bind the `update_year` function to changes in the horizontal slider and use it to interactively change the plot

# %%
import pandas as pd

# %%
fertility = pd.read_csv("data/gapminder/fertility.csv", index_col="Country")
fertility.head()
# Out:
#                  1964   1965   1966   1967   1968   1969   1970   1971   1972  \
# Country
# Afghanistan     7.671  7.671  7.671  7.671  7.671  7.671  7.671  7.671  7.671
# Albania         5.711  5.594  5.483  5.376  5.268  5.160  5.050  4.933  4.809
# Algeria         7.653  7.655  7.657  7.658  7.657  7.652  7.641  7.622  7.591
# American Samoa    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Andorra           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                  1973  ...     2004   2005   2006   2007   2008   2009   2010  \
# Country                ...
# Afghanistan     7.671  ...    7.136  6.930  6.702  6.456  6.196  5.928  5.659
# Albania         4.677  ...    2.004  1.919  1.849  1.796  1.761  1.744  1.741
# Algeria         7.548  ...    2.448  2.507  2.580  2.656  2.725  2.781  2.817
# American Samoa    NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Andorra           NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                  2011   2012   2013
# Country
# Afghanistan     5.395  5.141  4.900
# Albania         1.748  1.760  1.771
# Algeria         2.829  2.820  2.795
# American Samoa    NaN    NaN    NaN
# Andorra           NaN    NaN    NaN
#
# [5 rows x 50 columns]

# %%
population = pd.read_csv("data/gapminder/population.csv", index_col="Country")
population.head()
# Out:
#                       1964        1965        1966        1967        1968  \
# Country
# Afghanistan     10474903.0  10697983.0  10927724.0  11163656.0  11411022.0
# Albania          1817098.0   1869942.0   1922993.0   1976140.0   2029314.0
# Algeria         11654905.0  11923002.0  12229853.0  12572629.0  12945462.0
# American Samoa     22672.0     23480.0     24283.0     25087.0     25869.0
# Andorra            17438.0     18529.0     19640.0     20772.0     21931.0
#
#                       1969        1970        1971        1972        1973  \
# Country
# Afghanistan     11676990.0  11964906.0  12273101.0  12593688.0  12915499.0
# Albania          2082474.0   2135599.0   2188650.0   2241623.0   2294578.0
# Algeria         13338918.0  13746185.0  14165889.0  14600659.0  15052371.0
# American Samoa     26608.0     27288.0     27907.0     28470.0     28983.0
# Andorra            23127.0     24364.0     25656.0     26997.0     28357.0
#
#                    ...            2004        2005        2006        2007  \
# Country            ...
# Afghanistan        ...      26693486.0  27614718.0  28420974.0  29145841.0
# Albania            ...       3124861.0   3141800.0   3156607.0   3169665.0
# Algeria            ...      32396048.0  32888449.0  33391954.0  33906605.0
# American Samoa     ...         61871.0     62962.0     64045.0     65130.0
# Andorra            ...         75292.0     77888.0     79874.0     81390.0
#
#                       2008        2009        2010        2011        2012  \
# Country
# Afghanistan     29839994.0  30577756.0  31411743.0  32358260.0  33397058.0
# Albania          3181397.0   3192723.0   3204284.0   3215988.0   3227373.0
# Algeria         34428028.0  34950168.0  35468208.0  35980193.0  36485828.0
# American Samoa     66217.0     67312.0     68420.0     69543.0     70680.0
# Andorra            82577.0     83677.0     84864.0     86165.0     87518.0
#
#                       2013
# Country
# Afghanistan     34499915.0
# Albania          3238316.0
# Algeria         36983924.0
# American Samoa     71834.0
# Andorra            88909.0
#
# [5 rows x 50 columns]

# %%
life_exp = pd.read_csv("data/gapminder/life_expectancy.csv", index_col="Country")
life_exp.head()
# Out:
#                   1964    1965    1966    1967    1968    1969    1970  \
# Country
# Afghanistan     33.639  34.152  34.662  35.170  35.674  36.172  36.663
# Albania         65.475  65.863  66.122  66.316  66.500  66.702  66.948
# Algeria         47.953  48.389  48.806  49.205  49.592  49.976  50.366
# American Samoa     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Andorra            NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                   1971    1972    1973   ...      2004    2005    2006  \
# Country                                  ...
# Afghanistan     37.143  37.614  38.075   ...    56.583  57.071  57.582
# Albania         67.251  67.595  67.966   ...    75.725  75.949  76.124
# Algeria         50.767  51.195  51.670   ...    69.682  69.854  70.020
# American Samoa     NaN     NaN     NaN   ...       NaN     NaN     NaN
# Andorra            NaN     NaN     NaN   ...       NaN     NaN     NaN
#
#                   2007    2008    2009    2010    2011    2012    2013
# Country
# Afghanistan     58.102  58.618  59.124  59.612  60.079  60.524  60.947
# Albania         76.278  76.433  76.598  76.780  76.979  77.185  77.392
# Algeria         70.180  70.332  70.477  70.615  70.747  70.874  71.000
# American Samoa     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Andorra            NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 50 columns]

# %%
regions = pd.read_csv("data/gapminder/regions.csv", index_col="Country")
regions.head()
# Out:
#                            Group  ID
# Country
# Angola        Sub-Saharan Africa  AO
# Benin         Sub-Saharan Africa  BJ
# Botswana      Sub-Saharan Africa  BW
# Burkina Faso  Sub-Saharan Africa  BF
# Burundi       Sub-Saharan Africa  BI

# %%
life_exp.head()
# Out:
#                   1964    1965    1966    1967    1968    1969    1970  \
# Country
# Afghanistan     33.639  34.152  34.662  35.170  35.674  36.172  36.663
# Albania         65.475  65.863  66.122  66.316  66.500  66.702  66.948
# Algeria         47.953  48.389  48.806  49.205  49.592  49.976  50.366
# American Samoa     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Andorra            NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                   1971    1972    1973   ...      2004    2005    2006  \
# Country                                  ...
# Afghanistan     37.143  37.614  38.075   ...    56.583  57.071  57.582
# Albania         67.251  67.595  67.966   ...    75.725  75.949  76.124
# Algeria         50.767  51.195  51.670   ...    69.682  69.854  70.020
# American Samoa     NaN     NaN     NaN   ...       NaN     NaN     NaN
# Andorra            NaN     NaN     NaN   ...       NaN     NaN     NaN
#
#                   2007    2008    2009    2010    2011    2012    2013
# Country
# Afghanistan     58.102  58.618  59.124  59.612  60.079  60.524  60.947
# Albania         76.278  76.433  76.598  76.780  76.979  77.185  77.392
# Algeria         70.180  70.332  70.477  70.615  70.747  70.874  71.000
# American Samoa     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Andorra            NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 50 columns]

# %%
life_exp.columns
# Out:
# Index(['1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972',
#        '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013'],
#       dtype='object')

# %%
life_exp[str(1991)]
# Out:
# Country
# Afghanistan                 49.439
# Albania                     71.799
# Algeria                     67.049
# American Samoa                 NaN
# Andorra                        NaN
# Angola                      41.221
# Anguilla                       NaN
# Antigua and Barbuda         71.568
# Argentina                   71.791
# Armenia                     67.864
# Aruba                       73.509
# Australia                   77.540
# Austria                     75.830
# Azerbaijan                  64.494
# Bahamas                     70.869
# Bahrain                     72.587
# Bangladesh                  60.537
# Barbados                    71.314
# Belarus                     70.580
# Belgium                     76.300
# Belize                      70.939
# Benin                       54.033
# Bermuda                        NaN
# Bhutan                      53.270
# Bolivia                     59.341
# Bosnia and Herzegovina      65.997
# Botswana                    62.444
# Brazil                      66.867
# British Virgin Islands         NaN
# Brunei                      73.814
#                              ...
# Tanzania                    50.177
# Thailand                    70.531
# Timor-Leste                 49.296
# Togo                        55.872
# Tokelau                        NaN
# Tonga                       69.722
# Trinidad and Tobago         68.094
# Tunisia                     69.387
# Turkey                      64.760
# Turkmenistan                62.764
# Turks and Caicos Islands       NaN
# Tuvalu                         NaN
# Uganda                      47.069
# Ukraine                     69.640
# United Arab Emirates        71.781
# United Kingdom              76.060
# United States               75.500
# Uruguay                     72.758
# Uzbekistan                  66.635
# Wallis et Futuna               NaN
# Vanuatu                     63.527
# Venezuela                   71.275
# West Bank and Gaza          68.421
# Western Sahara              58.086
# Vietnam                     70.981
# Virgin Islands (U.S.)       75.038
# Yemen, Rep.                 58.218
# Zambia                      43.062
# Zimbabwe                    57.990
# Åland                          NaN
# Name: 1991, Length: 244, dtype: float64

# %%
def by_year_alt(year):
    df = pd.concat([
        population[str(year)],
        fertility[str(year)],
        life_exp[str(year)],
        regions['Group']
    ], axis=1, sort=True)
    df.columns = ["P", "F", "LE", "G"]
    
    return df

# %%
def by_year(year):
    return pd.DataFrame({
        'Population': population[str(year)],
        'Fertility': fertility[str(year)],
        'Life expectancy': life_exp[str(year)],
        'Group': regions['Group'],
    })

# %%
df = by_year(1991)
df.head()
# Out:
#                 Population  Fertility  Life expectancy  \
# Afghanistan     14069854.0      7.700           49.439
# Albania          3291695.0      2.917           71.799
# Algeria         25930560.0      4.503           67.049
# American Samoa     48402.0        NaN              NaN
# Andorra            54996.0        NaN              NaN
#
#                                      Group
# Afghanistan                     South Asia
# Albania              Europe & Central Asia
# Algeria         Middle East & North Africa
# American Samoa         East Asia & Pacific
# Andorra              Europe & Central Asia

# %%
fig = go.FigureWidget()
fig
# Out:
# FigureWidget({
#     'data': [], 'layout': {}
# })

# %%
df.head()
# Out:
#                 Population  Fertility  Life expectancy  \
# Afghanistan     14069854.0      7.700           49.439
# Albania          3291695.0      2.917           71.799
# Algeria         25930560.0      4.503           67.049
# American Samoa     48402.0        NaN              NaN
# Andorra            54996.0        NaN              NaN
#
#                                      Group
# Afghanistan                     South Asia
# Albania              Europe & Central Asia
# Algeria         Middle East & North Africa
# American Samoa         East Asia & Pacific
# Andorra              Europe & Central Asia

# %%
for a, b in df.groupby("Group"):
    print(a, type(b))
# Out:
# America <class 'pandas.core.frame.DataFrame'>
# East Asia & Pacific <class 'pandas.core.frame.DataFrame'>
# Europe & Central Asia <class 'pandas.core.frame.DataFrame'>
# Middle East & North Africa <class 'pandas.core.frame.DataFrame'>
# South Asia <class 'pandas.core.frame.DataFrame'>
# Sub-Saharan Africa <class 'pandas.core.frame.DataFrame'>

# %%
for group_name, sub_df in df.groupby("Group"):
    sc = fig.add_scatter(
        x=sub_df['Fertility'],
        y=sub_df['Life expectancy'],
        mode='markers',
        marker={
            'size': np.sqrt(sub_df['Population'].fillna(0))/ 400
        },
        name=group_name,
    )

# %%
sc = fig.add_scatter(
    x=df['Fertility'],
    y=df['Life expectancy'],
    mode='markers',
)

# %%
pops = df['Population'].fillna(1)

# %%
pops.min()
# Out:
# 1.0

# %%
pops.max()
# Out:
# 1160799514.0

# %%
sc.marker.size = np.sqrt(pops)/ 400

# %%
sc.marker.size = pops / pops.max() * 100

# %%
sc.marker.size = np.sqrt(df['Population'].fillna(1))
